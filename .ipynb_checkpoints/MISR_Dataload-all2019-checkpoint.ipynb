# %% [markdown]
# # Package Installations

# %%
#conda install -c conda-forge gdal

# %%
#conda install -c conda-forge geopandas

# %%
#conda install -c conda-forge earthpy

# %%
#conda install -c conda-forge cloudpathlib

# %%
#conda install -c conda-forge pyhdf

# %%
#conda install -c conda-forge profilehooks

# %%
# !pip install netCDF4

# %%
#Import Packages. 
import sys
import os
import re
import warnings
import glob
import time
from datetime import datetime
from datetime import timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#from shapely.geometry import mapping, box
# import geopandas as gpd
# import earthpy as et
# import earthpy.spatial as es
# import earthpy.plot as ep
# from osgeo import gdal
import pandas as pd
import pyproj

from cloudpathlib import S3Path, S3Client
from pyhdf.SD import SD, SDC

import boto3
import io
import pickle

# from profilehooks import profile

warnings.simplefilter('ignore')

# %% [markdown]
# # Prepping labels data

# %%
train_labels = pd.read_csv('train_labels.csv',delimiter='|')

# %%
def min_lon_polygon(row):
    bounds_str = row['wkt'].replace("POLYGON ((","").replace("))",",")
    bounds = bounds_str.split(",")
    lons=[]
    for b in bounds:
        lon_lat = b.strip().split(" ")
        if(len(lon_lat[0])>0):
            lons.append(float(lon_lat[0]))
    return min(lons)

def max_lon_polygon(row):
    bounds_str = row['wkt'].replace("POLYGON ((","").replace("))",",")
    bounds = bounds_str.split(",")
    lons=[]
    for b in bounds:
        lon_lat = b.strip().split(" ")
        if(len(lon_lat[0])>0):
            lons.append(float(lon_lat[0]))
    return max(lons)

# %%
def min_lat_polygon(row):
    bounds_str = row['wkt'].replace("POLYGON ((","").replace("))",",")
    bounds = bounds_str.split(",")
    lats=[]
    for b in bounds:
        lon_lat = b.strip().split(" ")
        if(len(b)>0 and len(lon_lat[1])>0):
            lats.append(float(lon_lat[1]))
    return min(lats)

def max_lat_polygon(row):
    bounds_str = row['wkt'].replace("POLYGON ((","").replace("))",",")
    bounds = bounds_str.split(",")
    lats=[]
    for b in bounds:
        lon_lat = b.strip().split(" ")
        if(len(b)>0 and len(lon_lat[1])>0):
            lats.append(float(lon_lat[1]))
    return max(lats)

# %%
def location_code(row):
    if(row['location']=='Los Angeles (SoCAB)'):
        return 'la'
    if(row['location']=='Delhi'):
        return 'dl'
    if(row['location']=='Taipei'):
        return 'tpe'

# %%
def utc_year(row):
    dt_str=row['datetime'][:row['datetime'].find("T")]
    dt= datetime.strptime(dt_str,"%Y-%m-%d")
    return dt.year
def utc_month(row):
    dt_str=row['datetime'][:row['datetime'].find("T")]
    dt= datetime.strptime(dt_str,"%Y-%m-%d")
    return dt.month
def utc_date(row):
    return row['datetime'][:row['datetime'].find("T")]

# %%
train_labels["min_lon"] = train_labels.apply(lambda row: min_lon_polygon(row), axis=1)
train_labels["max_lon"] = train_labels.apply(lambda row: max_lon_polygon(row), axis=1)
train_labels["min_lat"] = train_labels.apply(lambda row: min_lat_polygon(row), axis=1)
train_labels["max_lat"] = train_labels.apply(lambda row: max_lat_polygon(row), axis=1)
train_labels["loc"] = train_labels.apply(lambda row: location_code(row), axis=1)
train_labels["utc_date"] = train_labels.apply(lambda row: utc_date(row), axis=1)

# %%
train_labels[0:4]
# Out:
#                datetime grid_id  value             location         tz  \
# 0  2018-02-01T08:00:00Z   3S31A   11.4  Los Angeles (SoCAB)  Etc/GMT+8
# 1  2018-02-01T08:00:00Z   A2FBI   17.0  Los Angeles (SoCAB)  Etc/GMT+8
# 2  2018-02-01T08:00:00Z   DJN0F   11.1  Los Angeles (SoCAB)  Etc/GMT+8
# 3  2018-02-01T08:00:00Z   E5P9N   22.1  Los Angeles (SoCAB)  Etc/GMT+8
#
#                                                  wkt     min_lon     max_lon  \
# 0  POLYGON ((-117.9338248256995 33.79558357488509... -117.978741 -117.933825
# 1  POLYGON ((-117.3948356552278 33.98201108613195... -117.439751 -117.394836
# 2  POLYGON ((-117.6194144762577 34.09367183102137... -117.664330 -117.619414
# 3  POLYGON ((-117.4846671836398 33.98201108613195... -117.529583 -117.484667
#
#      min_lat    max_lat loc    utc_date
# 0  33.795584  33.832902  la  2018-02-01
# 1  33.982011  34.019248  la  2018-02-01
# 2  34.093672  34.130859  la  2018-02-01
# 3  33.982011  34.019248  la  2018-02-01

# %% [markdown]
# # PM25 Satellite Metadata

# %%
pm25_sat_metadata = pd.read_csv('pm25_satellite_metadata.csv')

# %%
pm25_sat_metadata = pm25_sat_metadata[pm25_sat_metadata['product']=='misr']

# %%
pm25_sat_metadata[0:4]
# Out:
#                         granule_id                time_start  \
# 6704  20180203T193400_misr_la_0.nc  2018-02-03T18:37:03.000Z
# 6705  20180205T192128_misr_la_0.nc  2018-02-05T18:24:29.000Z
# 6706  20180207T190854_misr_la_0.nc  2018-02-07T18:11:57.000Z
# 6707  20180210T193931_misr_la_0.nc  2018-02-10T18:42:33.000Z
#
#                        time_end product location  split  \
# 6704  2018-02-03 19:34:00+00:00    misr       la  train
# 6705  2018-02-05 19:21:28+00:00    misr       la  train
# 6706  2018-02-07 19:08:54+00:00    misr       la  train
# 6707  2018-02-10 19:39:31+00:00    misr       la  train
#
#                                                  us_url  \
# 6704  s3://drivendata-competition-airathon-public-us...
# 6705  s3://drivendata-competition-airathon-public-us...
# 6706  s3://drivendata-competition-airathon-public-us...
# 6707  s3://drivendata-competition-airathon-public-us...
#
#                                                  eu_url  \
# 6704  s3://drivendata-competition-airathon-public-eu...
# 6705  s3://drivendata-competition-airathon-public-eu...
# 6706  s3://drivendata-competition-airathon-public-eu...
# 6707  s3://drivendata-competition-airathon-public-eu...
#
#                                                  as_url       cksum  \
# 6704  s3://drivendata-competition-airathon-public-as...  1711515017
# 6705  s3://drivendata-competition-airathon-public-as...  2333466395
# 6706  s3://drivendata-competition-airathon-public-as...  2932143265
# 6707  s3://drivendata-competition-airathon-public-as...  3564723192
#
#       granule_size
# 6704      36930406
# 6705      35593605
# 6706      30668976
# 6707      42459135

# %%
pm25_sat_metadata = pm25_sat_metadata.rename(columns={"location": "loc"})

# %%
def utc_date_end(row):
    return row['time_end'][:row['time_end'].find(" ")]

# %%
pm25_sat_metadata['utc_date']=pm25_sat_metadata.apply(lambda row: utc_date_end(row), axis=1)

# %%
pm25_sat_metadata['time_end'].dtype
# Out:
# dtype('O')

# %%
pm25_sat_metadata.groupby(['loc','time_end']).count()
# Out:
#                                granule_id  time_start  product  split  us_url  \
# loc time_end
# dl  2017-11-06 06:29:11+00:00           1           1        1      1       1
#     2017-11-08 06:17:01+00:00           1           1        1      1       1
#     2017-11-15 06:23:44+00:00           1           1        1      1       1
#     2017-11-22 06:30:23+00:00           1           1        1      1       1
#     2017-11-24 06:18:08+00:00           1           1        1      1       1
# ...                                   ...         ...      ...    ...     ...
# tpe 2021-07-28 02:57:27+00:00           1           1        1      1       1
#     2021-08-04 03:04:00+00:00           1           1        1      1       1
#     2021-08-11 03:10:39+00:00           1           1        1      1       1
#     2021-08-13 02:58:27+00:00           1           1        1      1       1
#     2021-08-20 03:05:09+00:00           1           1        1      1       1
#
#                                eu_url  as_url  cksum  granule_size  utc_date
# loc time_end
# dl  2017-11-06 06:29:11+00:00       1       1      1             1         1
#     2017-11-08 06:17:01+00:00       1       1      1             1         1
#     2017-11-15 06:23:44+00:00       1       1      1             1         1
#     2017-11-22 06:30:23+00:00       1       1      1             1         1
#     2017-11-24 06:18:08+00:00       1       1      1             1         1
# ...                               ...     ...    ...           ...       ...
# tpe 2021-07-28 02:57:27+00:00       1       1      1             1         1
#     2021-08-04 03:04:00+00:00       1       1      1             1         1
#     2021-08-11 03:10:39+00:00       1       1      1             1         1
#     2021-08-13 02:58:27+00:00       1       1      1             1         1
#     2021-08-20 03:05:09+00:00       1       1      1             1         1
#
# [1017 rows x 10 columns]

# %% [markdown]
# # Merge PM25 Satellite Metadata and Labels Data

# %%
#datetime(02/01 6am)

#time_end (02/01 noon)   -   datetime(02/02 6am)   YES

#time_end (02/02 noon)   -   datetime(02/02 6am)   NO

test=0
if(not test):
    pm25_sat_metadata = pm25_sat_metadata[pm25_sat_metadata['split']=='train']
    all_metadata_new = pd.merge(train_labels, pm25_sat_metadata, on=['loc'])
    all_metadata_new = all_metadata_new[(all_metadata_new['time_end'].astype('datetime64[ns]')<=
                                         all_metadata_new['datetime'].astype('datetime64[ns]') + timedelta(days=1)) &
                                        (all_metadata_new['time_end'].astype('datetime64[ns]') >=
                                         all_metadata_new['datetime'].astype('datetime64[ns]'))
                                       ]

else:
    all_metadata_new = pm25_sat_metadata
    all_metadata_new = all_metadata_new[(all_metadata_new['time_end'].astype('datetime64[ns]')<=
                                         all_metadata_new['datetime'].astype('datetime64[ns]') + timedelta(days=1)) &
                                        (all_metadata_new['time_end'].astype('datetime64[ns]') >=
                                         all_metadata_new['datetime'].astype('datetime64[ns]'))
                                       ]

# %%
len(pm25_sat_metadata)
# Out:
# 788

# %%
len(train_labels)
# Out:
# 34312

# %%
len(all_metadata_new)
# Out:
# 8502

# %% [markdown]
# # Write AOD data averaged for every grid (of interest) boundary to S3 bucket

# %%
all_metadata = all_metadata_new

# %%
len(all_metadata)
# Out:
# 8502

# %%
all_metadata.rename(columns={'datetime': 'pm25_reading_date', 'time_end': 'misr_reading_end'}, inplace=True)

# %%
all_metadata['datetime_dt'] = pd.to_datetime(all_metadata['pm25_reading_date'], errors='coerce')
all_metadata['misr_read_end_dt'] = pd.to_datetime(all_metadata['misr_reading_end'], errors='coerce')

year_2018_metadata = all_metadata[all_metadata['datetime_dt'].dt.year==2018]

# %%
len(year_2018_metadata)
# Out:
# 1698

# %%
year_2019_metadata = all_metadata[all_metadata['datetime_dt'].dt.year==2019]

# %%
len(year_2019_metadata)
# Out:
# 2872

# %%
year_2020_metadata = all_metadata[all_metadata['datetime_dt'].dt.year==2020]

# %%
len(year_2020_metadata)
# Out:
# 3932

# %%
all_metadata['datetime_dt'].dt.year.unique()
# Out:
# array([2018, 2019, 2020])

# %%
all_metadata[0:6]
# Out:
#          pm25_reading_date grid_id  value             location         tz  \
# 4524  2018-02-03T08:00:00Z   3S31A   27.2  Los Angeles (SoCAB)  Etc/GMT+8
# 4901  2018-02-03T08:00:00Z   A2FBI   18.0  Los Angeles (SoCAB)  Etc/GMT+8
# 5278  2018-02-03T08:00:00Z   DJN0F   27.3  Los Angeles (SoCAB)  Etc/GMT+8
# 5655  2018-02-03T08:00:00Z   E5P9N   32.3  Los Angeles (SoCAB)  Etc/GMT+8
# 6032  2018-02-03T08:00:00Z   FRITQ   45.3  Los Angeles (SoCAB)  Etc/GMT+8
# 6409  2018-02-03T08:00:00Z   H96P6   12.8  Los Angeles (SoCAB)  Etc/GMT+8
#
#                                                     wkt     min_lon  \
# 4524  POLYGON ((-117.9338248256995 33.79558357488509... -117.978741
# 4901  POLYGON ((-117.3948356552278 33.98201108613195... -117.439751
# 5278  POLYGON ((-117.6194144762577 34.09367183102137... -117.664330
# 5655  POLYGON ((-117.4846671836398 33.98201108613195... -117.529583
# 6032  POLYGON ((-118.1584036467294 33.83290166381627... -118.203319
# 6409  POLYGON ((-118.5177297603772 34.16803061743935... -118.562646
#
#          max_lon    min_lat    max_lat  ... product  split  \
# 4524 -117.933825  33.795584  33.832902  ...    misr  train
# 4901 -117.394836  33.982011  34.019248  ...    misr  train
# 5278 -117.619414  34.093672  34.130859  ...    misr  train
# 5655 -117.484667  33.982011  34.019248  ...    misr  train
# 6032 -118.158404  33.832902  33.870203  ...    misr  train
# 6409 -118.517730  34.168031  34.205185  ...    misr  train
#
#                                                  us_url  \
# 4524  s3://drivendata-competition-airathon-public-us...
# 4901  s3://drivendata-competition-airathon-public-us...
# 5278  s3://drivendata-competition-airathon-public-us...
# 5655  s3://drivendata-competition-airathon-public-us...
# 6032  s3://drivendata-competition-airathon-public-us...
# 6409  s3://drivendata-competition-airathon-public-us...
#
#                                                  eu_url  \
# 4524  s3://drivendata-competition-airathon-public-eu...
# 4901  s3://drivendata-competition-airathon-public-eu...
# 5278  s3://drivendata-competition-airathon-public-eu...
# 5655  s3://drivendata-competition-airathon-public-eu...
# 6032  s3://drivendata-competition-airathon-public-eu...
# 6409  s3://drivendata-competition-airathon-public-eu...
#
#                                                  as_url       cksum  \
# 4524  s3://drivendata-competition-airathon-public-as...  1711515017
# 4901  s3://drivendata-competition-airathon-public-as...  1711515017
# 5278  s3://drivendata-competition-airathon-public-as...  1711515017
# 5655  s3://drivendata-competition-airathon-public-as...  1711515017
# 6032  s3://drivendata-competition-airathon-public-as...  1711515017
# 6409  s3://drivendata-competition-airathon-public-as...  1711515017
#
#      granule_size  utc_date_y               datetime_dt  \
# 4524     36930406  2018-02-03 2018-02-03 08:00:00+00:00
# 4901     36930406  2018-02-03 2018-02-03 08:00:00+00:00
# 5278     36930406  2018-02-03 2018-02-03 08:00:00+00:00
# 5655     36930406  2018-02-03 2018-02-03 08:00:00+00:00
# 6032     36930406  2018-02-03 2018-02-03 08:00:00+00:00
# 6409     36930406  2018-02-03 2018-02-03 08:00:00+00:00
#
#               misr_read_end_dt
# 4524 2018-02-03 19:34:00+00:00
# 4901 2018-02-03 19:34:00+00:00
# 5278 2018-02-03 19:34:00+00:00
# 5655 2018-02-03 19:34:00+00:00
# 6032 2018-02-03 19:34:00+00:00
# 6409 2018-02-03 19:34:00+00:00
#
# [6 rows x 25 columns]

# %%
year_2018_metadata_la = all_metadata[(all_metadata['datetime_dt'].dt.year==2018) & 
                                    (all_metadata['location']=='Los Angeles (SoCAB)')]

# %%
len(year_2018_metadata_la)
# Out:
# 1113

# %% [markdown]
# # Extracting MISR Data

# %%
import netCDF4 as nc

# %%
vars = ['Latitude','Longitude',
 'Elevation','Year','Day_Of_Year','Month','Day','Hour','Minute','Land_Water_Retrieval_Type',
 'Aerosol_Optical_Depth','Aerosol_Optical_Depth_Uncertainty','Angstrom_Exponent_550_860nm',
 'Absorption_Aerosol_Optical_Depth','Nonspherical_Aerosol_Optical_Depth',
 'Small_Mode_Aerosol_Optical_Depth','Medium_Mode_Aerosol_Optical_Depth','Large_Mode_Aerosol_Optical_Depth']

# %%
def get_misr_data(file_name, vars):
    ds = nc.Dataset(file_name)
    output = []
    for var in vars:
        #print(var)
        mdata = ds.groups['4.4_KM_PRODUCTS'].variables[var][:].astype(np.double)
        data = np.ma.getdata(mdata)

        if var in ['Latitude','Longitude','Year','Day_Of_Year','Month','Day','Hour','Minute']:
            data[data==mdata.get_fill_value()]=np.nan

        flat_data = data.ravel()
        #print(data.shape)
        if len(output)==0:
            output = flat_data
        else:
            output = np.column_stack((output, flat_data))
    return pd.DataFrame(output, columns = vars)

# %%
def misr_avg_5km(misr_file_path, min_lon, max_lon, min_lat, max_lat, grid_id, 
                 misr_reading_end, pm25_reading_date, s3_cli):
    
    start_time = time.time()
    misr_file = S3Path(misr_file_path, client=s3_cli)
    file_name = misr_file.fspath
    
    misr_data = get_misr_data(file_name, vars)
    print("--- Time taken to get misr data for one file %s seconds ---" % (time.time() - start_time))

    
    misr_avg_5km_df = misr_data.loc[(misr_data['Longitude']>=float(min_lon)) & (misr_data['Latitude']>=float(min_lat))
                            & (misr_data['Longitude']<=float(max_lon)) & (misr_data['Latitude']<=float(max_lat))]
    print(len(misr_avg_5km_df))
    #aod_avg_5km_df_meaned = aod_avg_5km_df[aod_avg_5km_df.columns.tolist()].mean()
    misr_avg_5km_df['grid_id']=grid_id
    misr_avg_5km_df['misr_reading_end'] = misr_reading_end
    misr_avg_5km_df['pm25_reading_date'] = pm25_reading_date
    return misr_avg_5km_df#.to_frame().transpose()

# %%
start_time = time.time()

# all_5km_dfs = []

s3_cli = S3Client(no_sign_request=True)

for row in year_2019_metadata.iterrows():
    row_data = row[1]
    print(row_data['us_url'])
    if(".nc" in row_data['us_url']):
        misr_avg_5km_df = misr_avg_5km(row_data['us_url'], 
                                  row_data['min_lon'], row_data['max_lon'], row_data['min_lat'], row_data['max_lat'], 
                                  row_data['grid_id'],row_data['misr_reading_end'],row_data['pm25_reading_date'], s3_cli)
#         all_5km_dfs.append(misr_avg_5km_df)
# all_2018_misr_df = pd.concat(all_5km_dfs, axis=0)
        output_fname = 'misr/misr_'+str(row_data['grid_id'])+'_'+str(row_data['misr_reading_end'])+'.parquet'
        misr_avg_5km_df.to_parquet('s3://particulate-articulate-capstone/train/'+output_fname)

print("--- Time taken write 2019 grid level misr data to parquet - %s seconds ---" % (time.time() - start_time))
# Out:
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 2.6131463050842285 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 2.135622262954712 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 2.137969732284546 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 1.8318934440612793 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 1.8798468112945557 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 1.842618465423584 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 1.8487153053283691 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 1.833385705947876 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 2.200752019882202 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 1.8456172943115234 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 1.8616113662719727 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180203T193400_misr_la_0.nc
# --- Time taken to get misr data for one file 1.8659796714782715 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.5762712955474854 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2239768505096436 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.223808765411377 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2447314262390137 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.250786542892456 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.240405559539795 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.250143051147461 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2389681339263916 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.230456829071045 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2256085872650146 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2438809871673584 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180205T192128_misr_la_0.nc
# --- Time taken to get misr data for one file 1.8961026668548584 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180207T190854_misr_la_0.nc
# --- Time taken to get misr data for one file 2.559642791748047 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180207T190854_misr_la_0.nc
# --- Time taken to get misr data for one file 2.163217544555664 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180207T190854_misr_la_0.nc
# --- Time taken to get misr data for one file 2.254021406173706 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180207T190854_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2629849910736084 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180207T190854_misr_la_0.nc
# --- Time taken to get misr data for one file 1.9144368171691895 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180207T190854_misr_la_0.nc
# --- Time taken to get misr data for one file 1.9116673469543457 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180207T190854_misr_la_0.nc
# --- Time taken to get misr data for one file 1.881300926208496 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180207T190854_misr_la_0.nc
# --- Time taken to get misr data for one file 1.90901780128479 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.737121343612671 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.1850457191467285 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.224632740020752 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.266160488128662 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2630510330200195 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2725698947906494 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2475178241729736 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.245819091796875 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.231142282485962 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2385032176971436 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.265857458114624 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180210T193931_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2735860347747803 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.729804515838623 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.248809337615967 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.237386465072632 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3178179264068604 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.335273504257202 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.31870698928833 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3249683380126953 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3192434310913086 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.31632661819458 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.284799337387085 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.244765520095825 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180214T191422_misr_la_0.nc
# --- Time taken to get misr data for one file 2.230682134628296 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 2.63742733001709 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 1.9001710414886475 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 1.876976728439331 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2215726375579834 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2483696937561035 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2613446712493896 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2664265632629395 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 2.265287160873413 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2259371280670166 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2875537872314453 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 1.9272489547729492 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180219T193222_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2720460891723633 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.889939785003662 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3089518547058105 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.288386106491089 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3376400470733643 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.325214147567749 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3603696823120117 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.340031623840332 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3395581245422363 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.331207752227783 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3227834701538086 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.315866708755493 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180221T191948_misr_la_0.nc
# --- Time taken to get misr data for one file 2.453352451324463 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.871950387954712 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.297710418701172 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.271665573120117 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2794837951660156 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3382349014282227 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3115200996398926 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.284970283508301 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.316906452178955 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3144655227661133 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.309952974319458 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3572375774383545 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180223T190712_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3219876289367676 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.650392532348633 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3294737339019775 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3315372467041016 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3226993083953857 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3350272178649902 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3750016689300537 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3687281608581543 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3597958087921143 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.376159191131592 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.362325429916382 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180302T191237_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3419840335845947 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.688354730606079 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.254120111465454 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2763094902038574 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.254572629928589 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3129565715789795 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2682301998138428 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.324939012527466 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2810218334198 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.30377197265625 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2897613048553467 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3270955085754395 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180307T193036_misr_la_0.nc
# --- Time taken to get misr data for one file 1.921210527420044 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.8636484146118164 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.274791955947876 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.270181655883789 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2840566635131836 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3367207050323486 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.293248414993286 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2992804050445557 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.305645227432251 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3075883388519287 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.336855411529541 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.31144118309021 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180309T191801_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2794973850250244 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 3.065561532974243 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3701937198638916 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.318007469177246 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3228471279144287 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3182458877563477 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3045804500579834 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.280627965927124 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.316779136657715 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2971346378326416 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.292433500289917 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.302424430847168 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180311T190526_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3060178756713867 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.624863386154175 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3141772747039795 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3064162731170654 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.312077522277832 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.316472291946411 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3446059226989746 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3162269592285156 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.328885555267334 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3299567699432373 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3218984603881836 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.328824043273926 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180314T193559_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3185861110687256 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.8257832527160645 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3043148517608643 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.281447410583496 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2676913738250732 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2935492992401123 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.289865493774414 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.264923095703125 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3490920066833496 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.294595241546631 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3160653114318848 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.295114278793335 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180316T192324_misr_la_0.nc
# --- Time taken to get misr data for one file 2.276567220687866 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.9923388957977295 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.32130765914917 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.314681053161621 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3039028644561768 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.329120635986328 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3196730613708496 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3343513011932373 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3475427627563477 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.398207902908325 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3544347286224365 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3328347206115723 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180318T191052_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3222334384918213 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.772461175918579 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.284724235534668 seconds ---
# 0
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.30851411819458 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.384282350540161 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.345787286758423 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3012824058532715 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2889018058776855 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3119194507598877 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3011982440948486 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2852234840393066 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.304304599761963 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180323T192856_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2944397926330566 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180325T191624_misr_la_0.nc
# --- Time taken to get misr data for one file 2.864833354949951 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180325T191624_misr_la_0.nc
# --- Time taken to get misr data for one file 2.284024477005005 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180325T191624_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2514126300811768 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180325T191624_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2868142127990723 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180325T191624_misr_la_0.nc
# --- Time taken to get misr data for one file 2.317610740661621 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180325T191624_misr_la_0.nc
# --- Time taken to get misr data for one file 2.3098268508911133 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180325T191624_misr_la_0.nc
# --- Time taken to get misr data for one file 2.2906665802001953 seconds ---
# 1
# s3://drivendata-competition-airathon-public-us/pm25/train/misr/2018/20180325T191624_misr_la_0.nc
